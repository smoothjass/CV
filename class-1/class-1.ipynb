# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("ydq2xfwd9a971.webp", 1)

# %%
plt.imshow(img)

# %%
# cv2.imshow("my image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
img_correct = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_correct)

# %%
img_gray = cv2.cvtColor(img_correct, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray, cmap="gray")

# %%
img
# Out:
# array([[[236, 206, 161],
#         [236, 206, 161],
#         [236, 206, 161],
#         ...,
#         [246, 216, 171],
#         [246, 216, 171],
#         [246, 216, 171]],
#
#        [[236, 206, 161],
#         [236, 206, 161],
#         [236, 206, 161],
#         ...,
#         [246, 216, 171],
#         [246, 216, 171],
#         [246, 216, 171]],
#
#        [[236, 206, 161],
#         [236, 206, 161],
#         [236, 206, 161],
#         ...,
#         [246, 217, 169],
#         [246, 217, 169],
#         [246, 217, 169]],
#
#        ...,
#
#        [[112, 130, 177],
#         [112, 130, 177],
#         [112, 130, 177],
#         ...,
#         [144, 146, 161],
#         [151, 153, 168],
#         [157, 158, 174]],
#
#        [[112, 130, 177],
#         [112, 130, 177],
#         [112, 130, 177],
#         ...,
#         [144, 146, 161],
#         [151, 153, 168],
#         [157, 158, 174]],
#
#        [[112, 130, 177],
#         [112, 130, 177],
#         [112, 130, 177],
# ...

# %%
img_correct
# Out:
# array([[[161, 206, 236],
#         [161, 206, 236],
#         [161, 206, 236],
#         ...,
#         [171, 216, 246],
#         [171, 216, 246],
#         [171, 216, 246]],
#
#        [[161, 206, 236],
#         [161, 206, 236],
#         [161, 206, 236],
#         ...,
#         [171, 216, 246],
#         [171, 216, 246],
#         [171, 216, 246]],
#
#        [[161, 206, 236],
#         [161, 206, 236],
#         [161, 206, 236],
#         ...,
#         [169, 217, 246],
#         [169, 217, 246],
#         [169, 217, 246]],
#
#        ...,
#
#        [[177, 130, 112],
#         [177, 130, 112],
#         [177, 130, 112],
#         ...,
#         [161, 146, 144],
#         [168, 153, 151],
#         [174, 158, 157]],
#
#        [[177, 130, 112],
#         [177, 130, 112],
#         [177, 130, 112],
#         ...,
#         [161, 146, 144],
#         [168, 153, 151],
#         [174, 158, 157]],
#
#        [[177, 130, 112],
#         [177, 130, 112],
#         [177, 130, 112],
# ...

# %%
img_gray
# Out:
# array([[196, 196, 196, ..., 206, 206, 206],
#        [196, 196, 196, ..., 206, 206, 206],
#        [196, 196, 196, ..., 206, 206, 206],
#        ...,
#        [142, 142, 142, ..., 150, 157, 163],
#        [142, 142, 142, ..., 150, 157, 163],
#        [142, 142, 142, ..., 153, 155, 157]], dtype=uint8)

# %%
img_new = cv2.imread("ydq2xfwd9a971.webp", cv2.IMREAD_GRAYSCALE)

# %%
img_new
# Out:
# array([[196, 196, 196, ..., 206, 206, 206],
#        [196, 196, 196, ..., 206, 206, 206],
#        [196, 196, 196, ..., 206, 206, 206],
#        ...,
#        [142, 142, 142, ..., 150, 157, 163],
#        [142, 142, 142, ..., 150, 157, 163],
#        [142, 142, 142, ..., 153, 155, 157]], dtype=uint8)

# %%
plt.imshow(img_new, cmap="gray")

# %%
# cv2.imshow("gray", img_new)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
img_reverse = cv2.cvtColor(img_new, cv2.COLOR_GRAY2RGB)
plt.imshow(img_reverse)

# %%
img_reverse[370:400, 200:220, :] = np.array([200,90,130])

# %%
plt.imshow(img_reverse)

# %%
img_sobel = cv2.Sobel(img_gray, cv2.CV_16S, 0, 1, ksize=3)
plt.imshow(img_sobel, cmap="gray")

# %%
hist = cv2.calcHist([img_gray], [0], None, [256], [0,256])
plt.plot(hist, color="b")
